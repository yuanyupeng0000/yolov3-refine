# %%
import sys  
sys.path.insert(0, '/data/ssd-caffe/yolov3-caffe/python')
import caffe  
import numpy as np  
from collections import OrderedDict
from ConfigParser import ConfigParser

class uniqdict(OrderedDict):
    _unique = 0
    def __setitem__(self, key, val):
        if isinstance(val, OrderedDict):
            self._unique += 1
            key += "_"+str(self._unique)
        OrderedDict.__setitem__(self, key, val)
        
def load_conv2caffe(buf, start, conv_param):  
    weight = conv_param[0].data  
    bias = conv_param[1].data  
    conv_param[1].data[...] = np.reshape(buf[start:start+bias.size], bias.shape);   start = start + bias.size  
    conv_param[0].data[...] = np.reshape(buf[start:start+weight.size], weight.shape); start = start + weight.size  
    return start
def load_fc2caffe(buf, start, fc_param):  
    weight = fc_param[0].data  
    bias = fc_param[1].data  
    fc_param[1].data[...] = np.reshape(buf[start:start+bias.size], bias.shape);   start = start + bias.size  
    fc_param[0].data[...] = np.reshape(buf[start:start+weight.size], weight.shape); start = start + weight.size  
    return start
def load_conv_bn2caffe(buf, start, conv_param, bn_param, scale_param): 
    conv_weight = conv_param[0].data  
    running_mean = bn_param[0].data  
    running_var = bn_param[1].data  
    scale_weight = scale_param[0].data  
    scale_bias = scale_param[1].data      
    scale_param[1].data[...] = np.reshape(buf[start:start+scale_bias.size], scale_bias.shape); start = start + scale_bias.size  
    #print scale_bias.size  
    #print scale_bias  
  
    scale_param[0].data[...] = np.reshape(buf[start:start+scale_weight.size], scale_weight.shape); start = start + scale_weight.size  
    #print scale_weight.size
    #print scale_weight
  
    bn_param[0].data[...] = np.reshape(buf[start:start+running_mean.size], running_mean.shape); start = start + running_mean.size  
    #print running_mean.size
    #print running_mean
  
    bn_param[1].data[...] = np.reshape(buf[start:start+running_var.size], running_var.shape); start = start + running_var.size  
    #print running_var.size
    #print running_var
  
    bn_param[2].data[...] = np.array([1.0])  
    conv_param[0].data[...] = np.reshape(buf[start:start+conv_weight.size], conv_weight.shape); start = start + conv_weight.size  
    #print conv_weight.size
    #print conv_weight
  
    return start

# %%
def darknet2caffe(cfgfile, weightfile, protofile, caffemodel='gene.caffemodel'):  
    #net_info = cfg2prototxt(cfgfile)
    #save_prototxt(net_info , protofile, region=False)  
    print('benchmark')
    net = caffe.Net(protofile, caffe.TEST)
    k_v_s = [(k, v) for k, v in net.params.items()]
    key_vecnums = [(vecs[0], len(vecs[1])) for vecs in k_v_s]
    print([(vecs[0], [vecs[1][i].data.shape for i in range(len(vecs[1]))])for vecs in k_v_s])
    print('benchmark')
    params = net.params
    print('benchmark')
  
    #blocks = parse_cfg(cfgfile)
    parser = ConfigParser(dict_type=uniqdict)
    parser.read(cfgfile)
    blocks = parser.sections()
    print(blocks)
    
  
    #Open the weights file  
    fp = open(weightfile, "rb")  
  
    #The first 4 values are header information   
    # 1. Major version number  
    # 2. Minor Version Number  
    # 3. Subversion number   
    # 4. IMages seen   
    header = np.fromfile(fp, dtype = np.int32, count = 5)
    #header = np.fromfile(fp, dtype = np.float32, count = 5)
    print(header)
    #fp = open(weightfile, 'rb')  
    #header = np.fromfile(fp, count=5, dtype=np.int32)  
    #header = np.ndarray(shape=(5,),dtype='int32',buffer=fp.read(20))  
    #print(header)  
    buf = np.fromfile(fp, dtype = np.float32)
    print('buf len:{0}'.format(len(buf)))
    #print(buf)  
    fp.close()  
  
    layers = []  
    layer_id = 1  
    start = 0  
    for block in blocks:
        print(block)
        if start >= buf.size:  
            break
        items = dict(parser.items(block))
        print(items)
        if block.split('_')[0] == 'net':  
            continue
        elif ((block.split('_')[0] == 'convolutional') or 
        (block.split('_')[0] == 'deconvolutional')):
            batchnorm_followed = False
            relu_followed = False
            
            if 'batch_normalize' in items and items['batch_normalize']:
                batchnorm_followed = True
            if 'activation' in items and items['activation'] != 'linear':
                relu_followed = True
            
            if items.has_key('name'):  
                conv_layer_name = items['name']  
                print('has key name ' + conv_layer_name)
                bn_layer_name = '%s-bn' % items['name']  
                scale_layer_name = '%s-scale' % items['name']  
            else:
                if(block.split('_')[0] == 'deconvolutional'):
                    conv_layer_name = 'layer%d-upsample' % layer_id  
                    print('has no name ' + conv_layer_name)
                    #bn_layer_name = 'layer%d-bn' % layer_id  
                    #scale_layer_name = 'layer%d-scale' % layer_id 
                else:
                    conv_layer_name = 'layer%d-conv' % layer_id  
                    print('has no name ' + conv_layer_name)
                    bn_layer_name = 'layer%d-bn' % layer_id  
                    scale_layer_name = 'layer%d-scale' % layer_id  
  
            if batchnorm_followed:
                print("load_conv_bn2caffe:")
                start = load_conv_bn2caffe(buf, start, params[conv_layer_name], 
                                           params[bn_layer_name], params[scale_layer_name])
            else:
                print("load_conv2caffe:")
                start = load_conv2caffe(buf, start, params[conv_layer_name])  
            layer_id = layer_id+1
            print('start:{0}'.format(start))
        elif block.split('_')[0] == 'connected':  
            if items.has_key('name'):  
                fc_layer_name = items['name']  
            else:  
                fc_layer_name = 'layer%d-fc' % layer_id  
            start = load_fc2caffe(buf, start, params[fc_layer_name])  
            layer_id = layer_id+1  
        elif block.split('_')[0] == 'maxpool':  
            layer_id = layer_id+1  
        elif block.split('_')[0] == 'avgpool':  
            layer_id = layer_id+1  
        elif block.split('_')[0] == 'region':  
            layer_id = layer_id + 1  
        elif block.split('_')[0] == 'route':  
            layer_id = layer_id + 1  
        elif block.split('_')[0] == 'shortcut':  
            layer_id = layer_id + 1  
        elif block.split('_')[0] == 'softmax':  
            layer_id = layer_id + 1  
        elif block.split('_')[0] == 'cost':  
            layer_id = layer_id + 1  
        elif block.split('_')[0] == 'upsample':  
            layer_id = layer_id + 1 
        elif block.split('_')[0] == 'yolo':  
            layer_id = layer_id + 1
        else:  
            print('unknow layer type %s ' % block.split('_')[0]) 
            layer_id = layer_id + 1 
    print('save caffemodel to %s' % caffemodel)  
    net.save(caffemodel)

# %%
cfgfile = 'yolov3.cfg'
weights = 'yolov3.weights'
prototxt = 'yolov3.prototxt'
caffemodel = 'Jenerated_yolov3_aaa.caffemodel'
darknet2caffe(cfgfile, weights, prototxt, caffemodel)
# Out:
# benchmark
# [('layer1-conv', [(32, 3, 3, 3)]), ('layer1-bn', [(32,), (32,), (1,)]), ('layer1-scale', [(32,), (32,)]), ('layer2-conv', [(64, 32, 3, 3)]), ('layer2-bn', [(64,), (64,), (1,)]), ('layer2-scale', [(64,), (64,)]), ('layer3-conv', [(32, 64, 1, 1)]), ('layer3-bn', [(32,), (32,), (1,)]), ('layer3-scale', [(32,), (32,)]), ('layer4-conv', [(64, 32, 3, 3)]), ('layer4-bn', [(64,), (64,), (1,)]), ('layer4-scale', [(64,), (64,)]), ('layer6-conv', [(128, 64, 3, 3)]), ('layer6-bn', [(128,), (128,), (1,)]), ('layer6-scale', [(128,), (128,)]), ('layer7-conv', [(64, 128, 1, 1)]), ('layer7-bn', [(64,), (64,), (1,)]), ('layer7-scale', [(64,), (64,)]), ('layer8-conv', [(128, 64, 3, 3)]), ('layer8-bn', [(128,), (128,), (1,)]), ('layer8-scale', [(128,), (128,)]), ('layer10-conv', [(64, 128, 1, 1)]), ('layer10-bn', [(64,), (64,), (1,)]), ('layer10-scale', [(64,), (64,)]), ('layer11-conv', [(128, 64, 3, 3)]), ('layer11-bn', [(128,), (128,), (1,)]), ('layer11-scale', [(128,), (128,)]), ('layer13-conv', [(256, 128, 3, 3)]), ('layer13-bn', [(256,), (256,), (1,)]), ('layer13-scale', [(256,), (256,)]), ('layer14-conv', [(128, 256, 1, 1)]), ('layer14-bn', [(128,), (128,), (1,)]), ('layer14-scale', [(128,), (128,)]), ('layer15-conv', [(256, 128, 3, 3)]), ('layer15-bn', [(256,), (256,), (1,)]), ('layer15-scale', [(256,), (256,)]), ('layer17-conv', [(128, 256, 1, 1)]), ('layer17-bn', [(128,), (128,), (1,)]), ('layer17-scale', [(128,), (128,)]), ('layer18-conv', [(256, 128, 3, 3)]), ('layer18-bn', [(256,), (256,), (1,)]), ('layer18-scale', [(256,), (256,)]), ('layer20-conv', [(128, 256, 1, 1)]), ('layer20-bn', [(128,), (128,), (1,)]), ('layer20-scale', [(128,), (128,)]), ('layer21-conv', [(256, 128, 3, 3)]), ('layer21-bn', [(256,), (256,), (1,)]), ('layer21-scale', [(256,), (256,)]), ('layer23-conv', [(128, 256, 1, 1)]), ('layer23-bn', [(128,), (128,), (1,)]), ('layer23-scale', [(128,), (128,)]), ('layer24-conv', [(256, 128, 3, 3)]), ('layer24-bn', [(256,), (256,), (1,)]), ('layer24-scale', [(256,), (256,)]), ('layer26-conv', [(128, 256, 1, 1)]), ('layer26-bn', [(128,), (128,), (1,)]), ('layer26-scale', [(128,), (128,)]), ('layer27-conv', [(256, 128, 3, 3)]), ('layer27-bn', [(256,), (256,), (1,)]), ('layer27-scale', [(256,), (256,)]), ('layer29-conv', [(128, 256, 1, 1)]), ('layer29-bn', [(128,), (128,), (1,)]), ('layer29-scale', [(128,), (128,)]), ('layer30-conv', [(256, 128, 3, 3)]), ('layer30-bn', [(256,), (256,), (1,)]), ('layer30-scale', [(256,), (256,)]), ('layer32-conv', [(128, 256, 1, 1)]), ('layer32-bn', [(128,), (128,), (1,)]), ('layer32-scale', [(128,), (128,)]), ('layer33-conv', [(256, 128, 3, 3)]), ('layer33-bn', [(256,), (256,), (1,)]), ('layer33-scale', [(256,), (256,)]), ('layer35-conv', [(128, 256, 1, 1)]), ('layer35-bn', [(128,), (128,), (1,)]), ('layer35-scale', [(128,), (128,)]), ('layer36-conv', [(256, 128, 3, 3)]), ('layer36-bn', [(256,), (256,), (1,)]), ('layer36-scale', [(256,), (256,)]), ('layer38-conv', [(512, 256, 3, 3)]), ('layer38-bn', [(512,), (512,), (1,)]), ('layer38-scale', [(512,), (512,)]), ('layer39-conv', [(256, 512, 1, 1)]), ('layer39-bn', [(256,), (256,), (1,)]), ('layer39-scale', [(256,), (256,)]), ('layer40-conv', [(512, 256, 3, 3)]), ('layer40-bn', [(512,), (512,), (1,)]), ('layer40-scale', [(512,), (512,)]), ('layer42-conv', [(256, 512, 1, 1)]), ('layer42-bn', [(256,), (256,), (1,)]), ('layer42-scale', [(256,), (256,)]), ('layer43-conv', [(512, 256, 3, 3)]), ('layer43-bn', [(512,), (512,), (1,)]), ('layer43-scale', [(512,), (512,)]), ('layer45-conv', [(256, 512, 1, 1)]), ('layer45-bn', [(256,), (256,), (1,)]), ('layer45-scale', [(256,), (256,)]), ('layer46-conv', [(512, 256, 3, 3)]), ('layer46-bn', [(512,), (512,), (1,)]), ('layer46-scale', [(512,), (512,)]), ('layer48-conv', [(256, 512, 1, 1)]), ('layer48-bn', [(256,), (256,), (1,)]), ('layer48-scale', [(256,), (256,)]), ('layer49-conv', [(512, 256, 3, 3)]), ('layer49-bn', [(512,), (512,), (1,)]), ('layer49-scale', [(512,), (512,)]), ('layer51-conv', [(256, 512, 1, 1 ...
# benchmark
# benchmark
# ['net_1', 'convolutional_2', 'convolutional_3', 'convolutional_4', 'convolutional_5', 'shortcut_6', 'convolutional_7', 'convolutional_8', 'convolutional_9', 'shortcut_10', 'convolutional_11', 'convolutional_12', 'shortcut_13', 'convolutional_14', 'convolutional_15', 'convolutional_16', 'shortcut_17', 'convolutional_18', 'convolutional_19', 'shortcut_20', 'convolutional_21', 'convolutional_22', 'shortcut_23', 'convolutional_24', 'convolutional_25', 'shortcut_26', 'convolutional_27', 'convolutional_28', 'shortcut_29', 'convolutional_30', 'convolutional_31', 'shortcut_32', 'convolutional_33', 'convolutional_34', 'shortcut_35', 'convolutional_36', 'convolutional_37', 'shortcut_38', 'convolutional_39', 'convolutional_40', 'convolutional_41', 'shortcut_42', 'convolutional_43', 'convolutional_44', 'shortcut_45', 'convolutional_46', 'convolutional_47', 'shortcut_48', 'convolutional_49', 'convolutional_50', 'shortcut_51', 'convolutional_52', 'convolutional_53', 'shortcut_54', 'convolutional_55', 'convolutional_56', 'shortcut_57', 'convolutional_58', 'convolutional_59', 'shortcut_60', 'convolutional_61', 'convolutional_62', 'shortcut_63', 'convolutional_64', 'convolutional_65', 'convolutional_66', 'shortcut_67', 'convolutional_68', 'convolutional_69', 'shortcut_70', 'convolutional_71', 'convolutional_72', 'shortcut_73', 'convolutional_74', 'convolutional_75', 'shortcut_76', 'convolutional_77', 'convolutional_78', 'convolutional_79', 'convolutional_80', 'convolutional_81', 'convolutional_82', 'convolutional_83', 'yolo_84', 'route_85', 'convolutional_86', 'upsample_87', 'route_88', 'convolutional_89', 'convolutional_90', 'convolutional_91', 'convolutional_92', 'convolutional_93', 'convolutional_94', 'convolutional_95', 'yolo_96', 'route_97', 'convolutional_98', 'upsample_99', 'route_100', 'convolutional_101', 'convolutional_102', 'convolutional_103', 'convolutional_104', 'convolutional_105', 'convolutional_106', 'convolutional_107', 'yolo_108']
# [       0        2        0 32013312        0]
# buf len:62001757
# net_1
# {'hue': '.1', 'saturation': '1.5', 'angle': '0', 'decay': '0.0005', 'learning_rate': '0.001', 'scales': '.1,.1', 'batch': '1', 'height': '416', 'channels': '3', 'width': '416', 'subdivisions': '1', 'burn_in': '1000', 'policy': 'steps', 'max_batches': '500200', 'steps': '400000,450000', 'momentum': '0.9', 'exposure': '1.5'}
# convolutional_2
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '32', 'batch_normalize': '1', 'size': '3'}
# has no name layer1-conv
# load_conv_bn2caffe:
# start:992
# convolutional_3
# {'activation': 'leaky', 'stride': '2', 'pad': '1', 'filters': '64', 'batch_normalize': '1', 'size': '3'}
# has no name layer2-conv
# load_conv_bn2caffe:
# start:19680
# convolutional_4
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '32', 'batch_normalize': '1', 'size': '1'}
# has no name layer3-conv
# load_conv_bn2caffe:
# start:21856
# convolutional_5
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '64', 'batch_normalize': '1', 'size': '3'}
# has no name layer4-conv
# load_conv_bn2caffe:
# start:40544
# shortcut_6
# {'activation': 'linear', 'from': '-3'}
# convolutional_7
# {'activation': 'leaky', 'stride': '2', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '3'}
# has no name layer6-conv
# load_conv_bn2caffe:
# start:114784
# convolutional_8
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '64', 'batch_normalize': '1', 'size': '1'}
# has no name layer7-conv
# load_conv_bn2caffe:
# start:123232
# convolutional_9
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '3'}
# has no name layer8-conv
# load_conv_bn2caffe:
# start:197472
# shortcut_10
# {'activation': 'linear', 'from': '-3'}
# convolutional_11
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '64', 'batch_normalize': '1', 'size': '1'}
# has no name layer10-conv
# load_conv_bn2caffe:
# start:205920
# convolutional_12
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '3'}
# has no name layer11-conv
# load_conv_bn2caffe:
# start:280160
# shortcut_13
# {'activation': 'linear', 'from': '-3'}
# convolutional_14
# {'activation': 'leaky', 'stride': '2', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '3'}
# has no name layer13-conv
# load_conv_bn2caffe:
# start:576096
# convolutional_15
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '1'}
# has no name layer14-conv
# load_conv_bn2caffe:
# start:609376
# convolutional_16
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '3'}
# has no name layer15-conv
# load_conv_bn2caffe:
# start:905312
# shortcut_17
# {'activation': 'linear', 'from': '-3'}
# convolutional_18
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '1'}
# has no name layer17-conv
# load_conv_bn2caffe:
# start:938592
# convolutional_19
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '3'}
# has no name layer18-conv
# load_conv_bn2caffe:
# start:1234528
# shortcut_20
# {'activation': 'linear', 'from': '-3'}
# convolutional_21
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '1'}
# has no name layer20-conv
# load_conv_bn2caffe:
# start:1267808
# convolutional_22
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '3'}
# has no name layer21-conv
# load_conv_bn2caffe:
# start:1563744
# shortcut_23
# {'activation': 'linear', 'from': '-3'}
# convolutional_24
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '1'}
# has no name layer23-conv
# load_conv_bn2caffe:
# start:1597024
# convolutional_25
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '3'}
# has no name layer24-conv
# load_conv_bn2caffe:
# start:1892960
# shortcut_26
# {'activation': 'linear', 'from': '-3'}
# convolutional_27
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '1'}
# has no name layer26-conv
# load_conv_bn2caffe:
# start:1926240
# convolutional_28
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '3'}
# has no name layer27-conv
# load_conv_bn2caffe:
# start:2222176
# shortcut_29
# {'activation': 'linear', 'from': '-3'}
# convolutional_30
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '1'}
# has no name layer29-conv
# load_conv_bn2caffe:
# start:2255456
# convolutional_31
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '3'}
# has no name layer30-conv
# load_conv_bn2caffe:
# start:2551392
# shortcut_32
# {'activation': 'linear', 'from': '-3'}
# convolutional_33
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '1'}
# has no name layer32-conv
# load_conv_bn2caffe:
# start:2584672
# convolutional_34
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '3'}
# has no name layer33-conv
# load_conv_bn2caffe:
# start:2880608
# shortcut_35
# {'activation': 'linear', 'from': '-3'}
# convolutional_36
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '1'}
# has no name layer35-conv
# load_conv_bn2caffe:
# start:2913888
# convolutional_37
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '3'}
# has no name layer36-conv
# load_conv_bn2caffe:
# start:3209824
# shortcut_38
# {'activation': 'linear', 'from': '-3'}
# convolutional_39
# {'activation': 'leaky', 'stride': '2', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '3'}
# has no name layer38-conv
# load_conv_bn2caffe:
# start:4391520
# convolutional_40
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '1'}
# has no name layer39-conv
# load_conv_bn2caffe:
# start:4523616
# convolutional_41
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '3'}
# has no name layer40-conv
# load_conv_bn2caffe:
# start:5705312
# shortcut_42
# {'activation': 'linear', 'from': '-3'}
# convolutional_43
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '1'}
# has no name layer42-conv
# load_conv_bn2caffe:
# start:5837408
# convolutional_44
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '3'}
# has no name layer43-conv
# load_conv_bn2caffe:
# start:7019104
# shortcut_45
# {'activation': 'linear', 'from': '-3'}
# convolutional_46
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '1'}
# has no name layer45-conv
# load_conv_bn2caffe:
# start:7151200
# convolutional_47
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '3'}
# has no name layer46-conv
# load_conv_bn2caffe:
# start:8332896
# shortcut_48
# {'activation': 'linear', 'from': '-3'}
# convolutional_49
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '1'}
# has no name layer48-conv
# load_conv_bn2caffe:
# start:8464992
# convolutional_50
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '3'}
# has no name layer49-conv
# load_conv_bn2caffe:
# start:9646688
# shortcut_51
# {'activation': 'linear', 'from': '-3'}
# convolutional_52
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '1'}
# has no name layer51-conv
# load_conv_bn2caffe:
# start:9778784
# convolutional_53
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '3'}
# has no name layer52-conv
# load_conv_bn2caffe:
# start:10960480
# shortcut_54
# {'activation': 'linear', 'from': '-3'}
# convolutional_55
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '1'}
# has no name layer54-conv
# load_conv_bn2caffe:
# start:11092576
# convolutional_56
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '3'}
# has no name layer55-conv
# load_conv_bn2caffe:
# start:12274272
# shortcut_57
# {'activation': 'linear', 'from': '-3'}
# convolutional_58
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '1'}
# has no name layer57-conv
# load_conv_bn2caffe:
# start:12406368
# convolutional_59
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '3'}
# has no name layer58-conv
# load_conv_bn2caffe:
# start:13588064
# shortcut_60
# {'activation': 'linear', 'from': '-3'}
# convolutional_61
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '1'}
# has no name layer60-conv
# load_conv_bn2caffe:
# start:13720160
# convolutional_62
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '3'}
# has no name layer61-conv
# load_conv_bn2caffe:
# start:14901856
# shortcut_63
# {'activation': 'linear', 'from': '-3'}
# convolutional_64
# {'activation': 'leaky', 'stride': '2', 'pad': '1', 'filters': '1024', 'batch_normalize': '1', 'size': '3'}
# has no name layer63-conv
# load_conv_bn2caffe:
# start:19624544
# convolutional_65
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '1'}
# has no name layer64-conv
# load_conv_bn2caffe:
# start:20150880
# convolutional_66
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '1024', 'batch_normalize': '1', 'size': '3'}
# has no name layer65-conv
# load_conv_bn2caffe:
# start:24873568
# shortcut_67
# {'activation': 'linear', 'from': '-3'}
# convolutional_68
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '1'}
# has no name layer67-conv
# load_conv_bn2caffe:
# start:25399904
# convolutional_69
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '1024', 'batch_normalize': '1', 'size': '3'}
# has no name layer68-conv
# load_conv_bn2caffe:
# start:30122592
# shortcut_70
# {'activation': 'linear', 'from': '-3'}
# convolutional_71
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '1'}
# has no name layer70-conv
# load_conv_bn2caffe:
# start:30648928
# convolutional_72
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '1024', 'batch_normalize': '1', 'size': '3'}
# has no name layer71-conv
# load_conv_bn2caffe:
# start:35371616
# shortcut_73
# {'activation': 'linear', 'from': '-3'}
# convolutional_74
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '1'}
# has no name layer73-conv
# load_conv_bn2caffe:
# start:35897952
# convolutional_75
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '1024', 'batch_normalize': '1', 'size': '3'}
# has no name layer74-conv
# load_conv_bn2caffe:
# start:40620640
# shortcut_76
# {'activation': 'linear', 'from': '-3'}
# convolutional_77
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '1'}
# has no name layer76-conv
# load_conv_bn2caffe:
# start:41146976
# convolutional_78
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '1024', 'batch_normalize': '1', 'size': '3'}
# has no name layer77-conv
# load_conv_bn2caffe:
# start:45869664
# convolutional_79
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '1'}
# has no name layer78-conv
# load_conv_bn2caffe:
# start:46396000
# convolutional_80
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '1024', 'batch_normalize': '1', 'size': '3'}
# has no name layer79-conv
# load_conv_bn2caffe:
# start:51118688
# convolutional_81
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '1'}
# has no name layer80-conv
# load_conv_bn2caffe:
# start:51645024
# convolutional_82
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '1024', 'batch_normalize': '1', 'size': '3'}
# has no name layer81-conv
# load_conv_bn2caffe:
# start:56367712
# convolutional_83
# {'stride': '1', 'activation': 'linear', 'pad': '1', 'filters': '255', 'size': '1'}
# has no name layer82-conv
# load_conv2caffe:
# start:56629087
# yolo_84
# {'jitter': '.3', 'anchors': '10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326', 'random': '1', 'mask': '6,7,8', 'num': '9', 'classes': '80', 'ignore_thresh': '.7', 'truth_thresh': '1'}
# route_85
# {'layers': '-4'}
# convolutional_86
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '1'}
# has no name layer85-conv
# load_conv_bn2caffe:
# start:56761183
# upsample_87
# {'stride': '2'}
# route_88
# {'layers': '-1, 61'}
# convolutional_89
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '1'}
# has no name layer88-conv
# load_conv_bn2caffe:
# start:56958815
# convolutional_90
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '3'}
# has no name layer89-conv
# load_conv_bn2caffe:
# start:58140511
# convolutional_91
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '1'}
# has no name layer90-conv
# load_conv_bn2caffe:
# start:58272607
# convolutional_92
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '3'}
# has no name layer91-conv
# load_conv_bn2caffe:
# start:59454303
# convolutional_93
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '1'}
# has no name layer92-conv
# load_conv_bn2caffe:
# start:59586399
# convolutional_94
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '512', 'batch_normalize': '1', 'size': '3'}
# has no name layer93-conv
# load_conv_bn2caffe:
# start:60768095
# convolutional_95
# {'stride': '1', 'activation': 'linear', 'pad': '1', 'filters': '255', 'size': '1'}
# has no name layer94-conv
# load_conv2caffe:
# start:60898910
# yolo_96
# {'jitter': '.3', 'anchors': '10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326', 'random': '1', 'mask': '3,4,5', 'num': '9', 'classes': '80', 'ignore_thresh': '.7', 'truth_thresh': '1'}
# route_97
# {'layers': '-4'}
# convolutional_98
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '1'}
# has no name layer97-conv
# load_conv_bn2caffe:
# start:60932190
# upsample_99
# {'stride': '2'}
# route_100
# {'layers': '-1, 36'}
# convolutional_101
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '1'}
# has no name layer100-conv
# load_conv_bn2caffe:
# start:60981854
# convolutional_102
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '3'}
# has no name layer101-conv
# load_conv_bn2caffe:
# start:61277790
# convolutional_103
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '1'}
# has no name layer102-conv
# load_conv_bn2caffe:
# start:61311070
# convolutional_104
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '3'}
# has no name layer103-conv
# load_conv_bn2caffe:
# start:61607006
# convolutional_105
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '128', 'batch_normalize': '1', 'size': '1'}
# has no name layer104-conv
# load_conv_bn2caffe:
# start:61640286
# convolutional_106
# {'activation': 'leaky', 'stride': '1', 'pad': '1', 'filters': '256', 'batch_normalize': '1', 'size': '3'}
# has no name layer105-conv
# load_conv_bn2caffe:
# start:61936222
# convolutional_107
# {'stride': '1', 'activation': 'linear', 'pad': '1', 'filters': '255', 'size': '1'}
# has no name layer106-conv
# load_conv2caffe:
# start:62001757
# yolo_108
# save caffemodel to Jenerated_yolov3_aaa.caffemodel
